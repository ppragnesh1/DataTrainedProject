# %%
# https://www.kaggle.com/code/nguyenngocphung/data-visualization-beginer-tutorial
#https://thecleverprogrammer.com/2020/05/30/data-science-project-world-happiness-report-with-python/
#https://towardsdatascience.com/happiness-and-life-satisfaction-ecdc7d0ab9a5

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# call CSV file to DataFrame 

df = pd.read_csv("happiness_score_dataset.csv")

# %%
# Show the shape of the Data Row and columns

df.shape
# Out:
# (158, 12)

# %%
# Checking 5 top rows of the Data

df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
#columns description and what is their importanace to the happiness score

df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# Going to the Data column by column to understand which is relavant for our analysis
#
# -- Country : Represent name of Country   - Not Relavant
#
# -- Region : Geographic location of Country - Not Relavant for our
#
# -- Happiness Rank : Show the Rank of the country, lowest the Rank mean higher the happiness Rank
#
# -- Happiness Score : Higher the Score mean Getting top position on the Rank.
#
# -- Standar Error : this is related to standar error of ladder score
#
# -- Economy GDP per Capital : Gross Domestic product / by its population
#
# -- Family :family and happiness extends beyond money or possessions. Researchers followed up hundreds of families for a decade and found that the quality of family bonds mattered more to overall happiness than income.
#
# -- Health (Life Expectancy) : Higher life expectancy means healthy populations, accessible healthcare, and higher quality of life in general. As such, this variable introduces physical well-being and health as the determinants of countries’ happiness index. Countries with higher healthy life expectancy are rated higher in the WHI.
#
# -- Freedom :Freedom is one of the fundamental factors which affect happiness in different countries. Each person wants to have some level of control over their life and make their own life choices. Freedom means opportunity: opportunity to travel, to vote and be elected, to participate in demonstrations, to choose a carrier, etc.
#
# --Trust (Government Corruption) : Curruption is highly related to happiness rating,  when government is full of corruption then people situaiton are measurable.
#
# --Generosit - While generosity is not the most important aspect of happiness making other people happy is definitely a way of raising the happiness of our country a significant amount.
#
# -- Dystopia : Dystopia is an imaginary country that has the world’s least happy people, while residuals refer to the unexplained components that contribute to a country’s happiness.

# %% [markdown]
# "============================================================================================================================="
# From above observation we can conclude that  some columns are irrevant for Happniness scoring.
#
# ---> Country Column
# ---> Country Rank
# ---> Region
# ---> Dystopia Residual

# %% [markdown]
# # Data Exploration

# %%
# Checking the information about the Data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# Observation  :
#
#     ---> Country - String data type
#     ---> Region  - String data type
#     ---> Happiness Rank - integer data type
#     ---> All other columns - Float values
#
#     *******
#     ---->  NO missing values in any columns

# %%
# Checking the null values in data

df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# ** Observation :  There is no null value in data. **

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Heatmeap for null value show Zero null present

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Data has no duplicate values

# %%
# Checking the top 5 rows of the data.
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
# checking the sample 10 rows of data
df.sample(10)
# Out:
#                  Country                           Region  Happiness Rank  \
# 8            New Zealand        Australia and New Zealand               9
# 25               Germany                   Western Europe              26
# 79            Azerbaijan       Central and Eastern Europe              80
# 138  Congo (Brazzaville)               Sub-Saharan Africa             139
# 85               Romania       Central and Eastern Europe              86
# 41           El Salvador      Latin America and Caribbean              42
# 89           Philippines                Southeastern Asia              90
# 109                 Iran  Middle East and Northern Africa             110
# 71             Hong Kong                     Eastern Asia              72
# 35                 Spain                   Western Europe              36
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 8              7.286         0.03371                   1.25018  1.31967
# ...

# %%
#print(len(df["Region"].unique()))
#print(*df["Region"].unique(),sep="\n")
region = pd.Series(df["Region"].unique(),index = range(1,len(df["Region"].unique())+1))
region.to_frame(name="Region")
# Out:
#                              Region
# 1                    Western Europe
# 2                     North America
# 3         Australia and New Zealand
# 4   Middle East and Northern Africa
# 5       Latin America and Caribbean
# 6                 Southeastern Asia
# 7        Central and Eastern Europe
# 8                      Eastern Asia
# 9                Sub-Saharan Africa
# 10                    Southern Asia

# %% [markdown]
#  Observation : 158 Countries divided in above 10 Regions.

# %%
df["Country"].to_frame(name="Country")
# Out:
#          Country
# 0    Switzerland
# 1        Iceland
# 2        Denmark
# 3         Norway
# 4         Canada
# ..           ...
# 153       Rwanda
# 154        Benin
# 155        Syria
# 156      Burundi
# 157         Togo
#
# [158 rows x 1 columns]

# %% [markdown]
# Total number of countries in the world is 195 as per the google. and in our dataset we have 158, so remaing 37 countries data are not included in data.

# %%
# Top 10 Ranking Country with their Score 

df[df["Happiness Rank"]<=10][["Country","Happiness Score"]]
# Out:
#        Country  Happiness Score
# 0  Switzerland            7.587
# 1      Iceland            7.561
# 2      Denmark            7.527
# 3       Norway            7.522
# 4       Canada            7.427
# 5      Finland            7.406
# 6  Netherlands            7.378
# 7       Sweden            7.364
# 8  New Zealand            7.286
# 9    Australia            7.284

# %% [markdown]
# Top 10 Ranking country with their Happiness score.

# %%
# Bottom 10 Ranking Country with their Score

df[df["Happiness Rank"]>(df.shape[0]-10)][["Country","Happiness Score"]]
# Out:
#           Country  Happiness Score
# 148          Chad            3.667
# 149        Guinea            3.656
# 150   Ivory Coast            3.655
# 151  Burkina Faso            3.587
# 152   Afghanistan            3.575
# 153        Rwanda            3.465
# 154         Benin            3.340
# 155         Syria            3.006
# 156       Burundi            2.905
# 157          Togo            2.839

# %% [markdown]
# Bottom 10 Ranking Countries with their score

# %%
print(df["Happiness Score"].describe())
# Out:
# count    158.000000
# mean       5.375734
# std        1.145010
# min        2.839000
# 25%        4.526000
# 50%        5.232500
# 75%        6.243750
# max        7.587000
# Name: Happiness Score, dtype: float64

# %% [markdown]
# Description of Only Happiness column to check the mean value of Hapiness Score:  Mean is 5.37 and meadian is 5.23

# %%
CountryAboveAverage = df[df["Happiness Score"]>(df["Happiness Score"].mean())]
CountryBelowAverage = df[df["Happiness Score"]<(df["Happiness Score"].mean())]
print("Total Number of Country :",df.shape[0])
print("Number of Country Above Mean Average Score : ",CountryAboveAverage.shape[0])
print("Number of Country Below Mean Average Score : ",CountryBelowAverage.shape[0])
# Out:
# Total Number of Country : 158
# Number of Country Above Mean Average Score :  74
# Number of Country Below Mean Average Score :  84

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# ## Visulization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (20,15) )
plt.xticks(rotation=45, ha='right',fontsize=10)
print(df.groupby("Region")["Country"].count())
sns.countplot(x="Region",data=df)
# Out:
# Region
# Australia and New Zealand           2
# Central and Eastern Europe         29
# Eastern Asia                        6
# Latin America and Caribbean        22
# Middle East and Northern Africa    20
# North America                       2
# Southeastern Asia                   9
# Southern Asia                       7
# Sub-Saharan Africa                 40
# Western Europe                     21
# Name: Country, dtype: int64
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %% [markdown]
# Observation  :  Above Graph shows number of countries by Region vise.
#
#             --->  Highest number of countries are belongs to Sub-Saharan Africa
#             --->  Lowest Number of Countries are belongs to North America and  Australia and New Zealand

# %%
# Visulise "Happiness Score"
sns.distplot(a=df["Happiness Score"])
plt.show()

# %% [markdown]
# Observation : Happiness Score (Target Variable) : Data is distrbuted between the 4 and 6 score. and looks normal distrution.

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
# distplot or distribution plot combines the matplotlib.hist function with seaborn kdeplot()

columns = ['Standard Error', 'Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity', 'Dystopia Residual']

plt.figure(figsize=(20,30))

for i in range(len(columns)):
    
    plt.subplot(4,3,i+1)
    sns.histplot(df[columns[i]],color="c",kde=True,stat="density",linewidth=0)
    plt.title(columns[i])
    plt.tight_layout()

# %% [markdown]
# Observation :
#
# Standard column doen't have any relevance to Target Column.  But for the information from above graph we can see that Data is right skewed.
#
# GDP Per Capita : Data distribution are looks normal distribution
#
# Family : data is left skewed
#
# Health : Data is left skewed
#
# Freedom : data distribution looks normal
#
# Trust : data is right skewed
#
# Generosity : data is right skewed
#
# Dstopia :  dont have any relevance to "Happiness Score" , but data has normal distribution

# %%
# Checking statistical summary of the data
df.describe().T
# Out:
#                                count       mean        std      min  \
# Happiness Rank                 158.0  79.493671  45.754363  1.00000
# Happiness Score                158.0   5.375734   1.145010  2.83900
# Standard Error                 158.0   0.047885   0.017146  0.01848
# Economy (GDP per Capita)       158.0   0.846137   0.403121  0.00000
# Family                         158.0   0.991046   0.272369  0.00000
# Health (Life Expectancy)       158.0   0.630259   0.247078  0.00000
# Freedom                        158.0   0.428615   0.150693  0.00000
# Trust (Government Corruption)  158.0   0.143422   0.120034  0.00000
# Generosity                     158.0   0.237296   0.126685  0.00000
# Dystopia Residual              158.0   2.098977   0.553550  0.32858
#
#                                      25%        50%         75%        max
# Happiness Rank                 40.250000  79.500000  118.750000  158.00000
# ...

# %% [markdown]
# Observation  :
#
#     --->  Rank column   : has series of integer value so this description for rank is not relavant
#     --->  Score         : mean value is 5.37 and median is 5.23 so the difference is minor so we can                           say that distribution of the data is normal
#                           maximum score is 7.58 and minimum is 2.83 , mean/median difference is not                             too big.
#
#     --->  Standar Error : Mean value is 0.478  and median is 0.439 has difference of 0.039 - so data                           is right skewed
#     --->  GDP column    : Mean value is 0.846  and median is 0.910 has difference of 0.064 - so data                           is left skewed
#     --->  Family        : Mean Value is 0.991  and median is 1.029 has difference of 0.038 - so data                           is left skewed
#     --->  Health        : Mean value is 0.630  and median is 0.696 has difference of 0.066 - so data                           is left skewed
#     --->  Freedom       : mean value is 0.428  and median is 0.435 has difference of 0.007 - so data                           is left skewed
#     --->  Trust         : Mean vlaue is 0.143  and median is 0.107 has difference of 0.036 - so data                           is left skewed
#     --->  Generosity    : Mean value is 0.237  and median is 0.216 has difference of 0.021 - so data                           is left skewed
#     --->  Dystopia      : Mean value is 2.098  and median is 2.095 has very minor difference.                                   Recalling our column information, this is irrelavant for happniess score.

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30,8))
sns.heatmap(df.corr(),annot=True,lw=0.1,linecolor="black",fmt="0.2f")
plt.show()

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# # Dropping the irrelevant columns which has no contribution to Happiness score

# %%
df.drop(['Country', 'Region', 'Happiness Rank','Standard Error', 'Dystopia Residual'],axis=1,inplace=True)

# %%
# Running Heatmap for correlation after removing the unnecessary columns 
import matplotlib.pyplot as plt
plt.figure(figsize=(30,8))
sns.heatmap(df.corr(),annot=True,lw=0.1,linecolor="black",fmt="0.2f")
plt.show()

# %% [markdown]
# Observation : from the above correlation graph we can see that all features has positively correlated to target column.
#     Economy, Family, Health (life Expectancy) has very strong bond to the Hapiness score.
#     Freedom, Trust  has good bond with Happiness score
#     Generosity has low bond with Hapiness score.

# %%
sns.pairplot(df)

# %% [markdown]
# with above graph we can see the data distribution of with all each other columns which describe the how the data is correlated.
#
# Happiness Score - Economy (GDP per Capita) - Highly correlated - higher gdp higher the happiness
# Happiness Score - Family - Highly correlated - Higher the rate directly impact on happiness
# Happiness Score - Health (Life Expectancy) - Higher the rate for Health directely positively connected to Happiness.
# Happiness Score - Freedom  - Freedom has good positive correlation to Happiness score too.
# Happiness Score - Trust (Government Corruption) - Trust and Happiness has direct relation
# Happiness Score - Generosity - Generosity has overall not good bond with happiness.

# %% [markdown]
# # Outliers Checking

# %%
collist = df.columns.values
ncol=30
nrow=14
plt.figure(figsize=(ncol,5*nrow))
for i  in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(df[collist[i]],color="green",orient="h")
    plt.tight_layout()

# %% [markdown]
# we can see some outliers in Government Corruption are very high compare to (Family and Generosity)
#
# Remaining columns have no outliers.

# %% [markdown]
# ## Checking Skewness

# %%
df.skew()
# Out:
# Happiness Score                  0.097769
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# dtype: float64

# %% [markdown]
# Outcome of the skewness threshold is taken +/- 0.65. Columns which are having skewness:
#     Family
#     Health (Life Expectany)
#     Trust (Government Corruption)
#     gEnerosity

# %% [markdown]
# # Removing Outliers

# %% [markdown]
# ## Z Score Technique:

# %%
from scipy.stats import zscore
import numpy as np
z = np.abs(zscore(df))
threshold = 3
np.where(z>3)
# Out:
# (array([ 27, 128, 147, 153, 157], dtype=int64),
#  array([5, 6, 2, 5, 2], dtype=int64))

# %%
dfnew = df[(z<3).all(axis=1)]

# %%
dfnew.shape
# Out:
# (153, 7)

# %% [markdown]
# ## Percentage of Dataloss

# %%
loss_percentage = (158-153)/158*100
print(loss_percentage)
# Out:
# 3.1645569620253164

# %% [markdown]
# Data loss is just 3.16% which is acceptable.

# %% [markdown]
# ## Separating the Columns into Features and Target

# %%
x = dfnew.iloc[:,1:]
y = dfnew.iloc[:,:1]

# %%
x.shape
# Out:
# (153, 6)

# %%
y.shape
# Out:
# (153, 1)

# %% [markdown]
# ## Scaling the data unsing Min-Max Scaler

# %%
# from sklearn.preprocessing import MinMaxScaler
# mms = MinMaxScaler()
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_sc = sc.fit_transform(x)

# %%
x_sc
# Out:
# array([[ 1.38789292e+00,  1.36005144e+00,  1.25015165e+00,
#          1.58665486e+00,  2.49632535e+00,  5.27825034e-01],
#        [ 1.14530077e+00,  1.56864945e+00,  1.27650855e+00,
#          1.34281629e+00,  2.52840140e-02,  1.69327791e+00],
#        [ 1.20495078e+00,  1.40385228e+00,  9.75521816e-01,
#          1.47937915e+00,  3.06265929e+00,  9.00465894e-01],
#        [ 1.54883977e+00,  1.28661481e+00,  1.01898397e+00,
#          1.61421922e+00,  2.01024942e+00,  9.47244393e-01],
#        [ 1.20703698e+00,  1.25361581e+00,  1.10294776e+00,
#          1.37064570e+00,  1.69543202e+00,  1.87546345e+00],
#        [ 1.11421374e+00,  1.23640410e+00,  1.03502015e+00,
#          1.42842484e+00,  2.44252407e+00, -6.88465062e-04],
#        [ 1.21515000e+00,  1.08569283e+00,  1.05035732e+00,
#          1.25661141e+00,  1.59395535e+00,  2.02573938e+00],
#        [ 1.22099653e+00,  1.12090759e+00,  1.12449380e+00,
#          1.54842257e+00,  2.66199068e+00,  1.07780652e+00],
# ...

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

for i in range(0,100):
    x_train,x_test,y_train,y_test = train_test_split(x_sc,y,test_size=0.20,random_state=i)
    lr.fit(x_train,y_train)
    pred_train = lr.predict(x_train)
    pred_test = lr.predict(x_test)
    print("At Random State :", i)
    print("Training Accurcy Score :",r2_score(y_train,pred_train)*100)
    print("Testing Accuracy Score :",r2_score(y_test,pred_test)*100)
    print("Difference :", (r2_score(y_train,pred_train)*100)-(r2_score(y_test,pred_test)*100))
    print("\n")
# Out:
# At Random State : 0
# Training Accurcy Score : 77.74719693498477
# Testing Accuracy Score : 77.09829963922472
# Difference : 0.648897295760051
#
#
# At Random State : 1
# Training Accurcy Score : 78.24394927731268
# Testing Accuracy Score : 73.73415768541417
# Difference : 4.509791591898505
#
#
# At Random State : 2
# Training Accurcy Score : 77.40416763678667
# Testing Accuracy Score : 75.40120072331166
# Difference : 2.0029669134750065
#
#
# At Random State : 3
# Training Accurcy Score : 78.20236362563242
# Testing Accuracy Score : 74.49791766762553
# Difference : 3.704445958006886
#
#
# At Random State : 4
# Training Accurcy Score : 74.91725871409291
# Testing Accuracy Score : 81.00947369081462
# Difference : -6.092214976721706
#
#
# At Random State : 5
# Training Accurcy Score : 78.47234292833471
# Testing Accuracy Score : 71.82111741032489
# Difference : 6.651225518009824
#
#
# At Random State : 6
# Training Accurcy Score : 76.86502230261121
# ...

# %% [markdown]
# At Random State  0 with diff of Accuracy train and test : 0.64
# At Random State 52 with diff of Accuracy Train and Test : 0.35
# At Random State 24 with diff of Accuracy Train and TEst :-0.43

# %% [markdown]
# so we will select Random State : 24

# %% [markdown]
# # Linear Regression Model

# %%
x_train,x_test,y_train,y_test=train_test_split(x_sc,y,test_size=0.2,random_state=52)
lr.fit(x_train,y_train)
pred_train=lr.predict(x_train)
pred_test=lr.predict(x_test)
print("LR - Accuracy Score ",r2_score(y_test,pred_test)*100)
# Out:
# LR - Accuracy Score  77.03173494113341

# %%
# Checking cross _val _score
train_accuracy = r2_score(y_train,pred_train)
test_accuracy = r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cvscore = cross_val_score(lr,x_sc,y,cv=j).mean()
    print("At Cross fold :", j)
    print("C V Score :",cvscore)
    print("Train Accuracy :",train_accuracy)
    print("Test Accuracy : ",test_accuracy)
    print("\n")
# Out:
# At Cross fold : 2
# C V Score : -1.839112432800526
# Train Accuracy : 0.7738719196611688
# Test Accuracy :  0.770317349411334
#
#
# At Cross fold : 3
# C V Score : -2.2324093870150623
# Train Accuracy : 0.7738719196611688
# Test Accuracy :  0.770317349411334
#
#
# At Cross fold : 4
# C V Score : -4.729738676108699
# Train Accuracy : 0.7738719196611688
# Test Accuracy :  0.770317349411334
#
#
# At Cross fold : 5
# C V Score : -6.0434060384075625
# Train Accuracy : 0.7738719196611688
# Test Accuracy :  0.770317349411334
#
#
# At Cross fold : 6
# C V Score : -9.181001300110958
# Train Accuracy : 0.7738719196611688
# Test Accuracy :  0.770317349411334
#
#
# At Cross fold : 7
# C V Score : -13.125266126813058
# Train Accuracy : 0.7738719196611688
# Test Accuracy :  0.770317349411334
#
#
# At Cross fold : 8
# C V Score : -16.128037733825973
# Train Accuracy : 0.7738719196611688
# Test Accuracy :  0.770317349411334
#
#
# At Cross fold : 9
# C V Score : -18.08297064361098
# ...

# %% [markdown]
# Lowest differnce we can see between CV score and Test Accuracy is at CV:6

# %% [markdown]
# ## Checking more models

# %%
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor, RandomForestRegressor, ExtraTreesRegressor
from sklearn.linear_model import SGDRegressor, LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor

from sklearn.model_selection import cross_validate, cross_val_score
from sklearn.metrics import explained_variance_score, max_error, mean_absolute_error, r2_score, explained_variance_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, mean_squared_error, mean_squared_log_error
from sklearn.metrics import median_absolute_error, mean_poisson_deviance, mean_gamma_deviance
from sklearn.model_selection import KFold

# %%
models=[("Linear Regression", LinearRegression()),
        ("Ridge Regression", Ridge()),
        ("Lasso Regression", Lasso()),
        ("Stochastic Gradient Descent", SGDRegressor()),
        ("Decision Tree", DecisionTreeRegressor()),
        ("Random Forest", RandomForestRegressor()),
        ("Gradient Boosting", GradientBoostingRegressor()),
        ("Ada Boost", AdaBoostRegressor()),
        ("XGBRegressor", XGBRegressor()),
        ("KNeighbors", KNeighborsRegressor()),
        ("SVM linear", SVR(kernel='linear')),
        ("SVM rbf", SVR(kernel='rbf'))]


for name,model in models:
    model.fit(x_train,y_train)
    modelpredict=model.predict(x_test)
    print("Model :",name)
    print("score: ", model.score(x_test, y_test))
    print("cross_val_score: ", cross_val_score(model,x_train, y_train, cv = 10).mean())
    print("r2_score: ", r2_score(y_test, modelpredict))
    print("")
    print("mean_absolute_error: ", mean_absolute_error(y_test, modelpredict))
    print("mean_squared_error: ", mean_squared_error(y_test, modelpredict))
    print("root_mean_squared_error: ", mean_squared_error(y_test, modelpredict, squared=False))
    print("max_error: ", max_error(y_test, modelpredict))
    print("========================\n")
# Out:
# Model : Linear Regression
# score:  0.7703173494113346
# cross_val_score:  0.7007450457851206
# r2_score:  0.7703173494113346
#
# mean_absolute_error:  0.35716452333983645
# mean_squared_error:  0.22732345030540654
# root_mean_squared_error:  0.4767844904203644
# max_error:  1.5189579471422832
# ...
#
# Model : Ridge Regression
# score:  0.7998279714844552
# cross_val_score:  0.7063421719774491
# r2_score:  0.7998279714844552
#
# mean_absolute_error:  0.33505814888134133
# mean_squared_error:  0.19811594850617523
# root_mean_squared_error:  0.44510217760214926
# max_error:  1.3520541940365645
# ...
#
# Model : Lasso Regression
# score:  -0.012216937548117812
# cross_val_score:  -0.060675945177947124
# r2_score:  -0.012216937548117812
#
# mean_absolute_error:  0.8640087255420414
# mean_squared_error:  1.001819885443126
# root_mean_squared_error:  1.0009095290999712
# max_error:  2.084909836065574
# ...
#
# Model : Stochastic Gradient Descent
# score:  0.7394839202949208
# ...

# %% [markdown]
# # Hyper parameter testing

# %%
from sklearn.model_selection import GridSearchCV

parameters = { 'loss' : ['ls', 'lad', 'huber', 'quantile'],
              'learning_rate' : (0.05,0.25,0.50,1),
              'criterion' : ['friedman_mse', 'mse', 'mae'],
              'max_features' : ['auto', 'sqrt', 'log2']
             }
grid = GridSearchCV(GradientBoostingRegressor(),parameters)
model = grid.fit(x_sc,y)
print(model.best_params_,"\n")
print(model.best_estimator_,"\n")
# Out:
# {'criterion': 'friedman_mse', 'learning_rate': 0.05, 'loss': 'lad', 'max_features': 'log2'}
#
# GradientBoostingRegressor(learning_rate=0.05, loss='lad', max_features='log2')

# %%
# Checking the GradientBoostingRegressior

FinalModel = GradientBoostingRegressor(learning_rate=0.05, loss='lad', max_features='log2')

FinalModel.fit(x_train,y_train)
modelpredict=FinalModel.predict(x_test)
print("score: ", FinalModel.score(x_test, y_test))
print("cross_val_score: ", cross_val_score(FinalModel,x_train, y_train, cv = 10).mean())
print("r2_score: ", r2_score(y_test, modelpredict))
print("")
print("mean_absolute_error: ", mean_absolute_error(y_test, modelpredict))
print("mean_squared_error: ", mean_squared_error(y_test, modelpredict))
print("root_mean_squared_error: ", mean_squared_error(y_test, modelpredict, squared=False))
print("max_error: ", max_error(y_test, modelpredict))
print("========================\n")
# Out:
# score:  0.818645862496878
# cross_val_score:  0.6805674799007189
# r2_score:  0.818645862496878
#
# mean_absolute_error:  0.31352835196754963
# mean_squared_error:  0.17949134668513472
# root_mean_squared_error:  0.4236641909403422
# max_error:  1.0965407183522533
# ...

# %% [markdown]
# # Saving Model

# %%
import pickle
filename = "WorldHappiness.pkl"
pickle.dump(FinalModel,open(filename,"wb"))

# %% [markdown]
# # End of Project
